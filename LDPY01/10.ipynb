# %% [markdown]
# ## Working with REST API's

# %% [markdown]
# Requests allows you to send HTTP/1.1 requests, without the need for manual labor. There's no need to manually add query strings to your URLs, or to form-encode your POST data. Keep-alive and HTTP connection pooling are 100% automatic, thanks to urllib3.

# %% [markdown]
# ### Make a HTTP GET Request and processing the Response

# %%
import requests

# %% [markdown]
# Let's try to get a webpage. For this example, let's get GitHub's public timeline:

# %%
r = requests.get('https://api.github.com/events')

# %% [markdown]
# Now, we have a Response object called r. We can get all the information we need from this object.

# %%
r.status_code
# Out:
# 200

# %% [markdown]
# Requests' simple API means that all forms of HTTP request are as obvious. For example, this is how you make an HTTP POST request:

# %%
[e for e in dir(r) if "_" not in e]
# Out:
# ['close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raw',
#  'reason',
#  'request',
#  'text',
#  'url']

# %%
r.text
# Out:
# '[{"id":"7395970984","type":"CreateEvent","actor":{"id":4142577,"login":"DouglasCAyers","display_login":"DouglasCAyers","gravatar_id":"","url":"https://api.github.com/users/DouglasCAyers","avatar_url":"https://avatars.githubusercontent.com/u/4142577?"},"repo":{"id":125696120,"name":"DouglasCAyers/sfdx-expense","url":"https://api.github.com/repos/DouglasCAyers/sfdx-expense"},"payload":{"ref":"1.0.0.1","ref_type":"tag","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2018-03-18T05:55:57Z"},{"id":"7395970983","type":"PullRequestEvent","actor":{"id":12693984,"login":"everypoliticianbot","display_login":"everypoliticianbot","gravatar_id":"","url":"https://api.github.com/users/everypoliticianbot","avatar_url":"https://avatars.githubusercontent.com/u/12693984?"},"repo":{"id":34725861,"name":"everypolitician/everypolitician-data","url":"https://api.github.com/repos/everypolitician/everypolitician-data"},"payload":{"action":"opened","number":85515,"pull_request":{"url":"https://api.github.com/repos/everypolitician/everypolitician-data/pulls/85515","id":175736716,"html_url":"https://github.com/everypolitician/everypolitician-data/pull/85515","diff_url":"https://github.com/everypolitician/everypolitician-data/pull/85515.diff","patch_url":"https://github.com/everypolitician/everypolitician-data/pull/85515.patch","issue_url":"https://api.github.com/repos/everypolitician/everypolitician-data/issues/85515","number":85515,"state":"open","locked":false,"title":"United States of America (Senate): refresh project","user":{"login":"everypoliticianbot","id":12693984,"avatar_url":"https://avatars3.githubusercontent.com/u/12693984?v=4","gravatar_id":"","url":"https://api.github.com/users/everypoliticianbot","html_url":"https://github.com/everypoliticianbot","followers_url":"https://api.github.com/users/everypoliticianbot/followers","following_url":"https://api.github.com/users/everypoliticianbot/following{/other_user}","gists_url":"https://api.github.com/users/everypoliticianbot/gists{/gist_id}","starred_url":"https://api.github.com/users/everypoliticianbot/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/everypoliticianbot/subscriptions","organizations_url":"https://api.github.com/users/everypoliticianbot/orgs","repos_url":"https://api.github.com/users/everypoliticianbot/repos","events_url":"https://api.github.com/users/everypoliticianbot/events{/privacy}","received_events_url":"https://api.github.com/users/everypoliticianbot/received_events","type":"User","site_admin":false},"body":"Automated refresh of project for United States of America - Senate\\n\\n#### Output\\n\\n```\\nSwitched to a new branch \'united-states-of-america-senate-1521352177\'\\n⤈ No ORDER BY for sources/morph/unitedstates-project.csv\\nAdd memberships from sources/morph/unitedstates-project.csv\\nMerging with sources/morph/socialmedia.csv\\nData Mismatches\\n* 499 of 609 unmatched\\n\\t{:id=>\\"L000491\\"}\\n\\t{:id=>\\"C001093\\"}\\n\\t{:id=>\\"B001290\\"}\\n\\t{:id=>\\"B001274\\"}\\n\\t{:id=>\\"K000376\\"}\\n\\t{:id=>\\"E000293\\"}\\n\\t{:id=>\\"S001193\\"}\\n\\t{:id=>\\"F000466\\"}\\n\\t{:id=>\\"M001194\\"}\\n\\t{:id=>\\"T000478\\"}\\nMerging with sources/morph/wikidata.csv\\nData Mismatches\\n  ☁ Mismatch in identifier__fec for 96324d91-c6e4-401a-b43e-a526dabe40a8 (S6AZ00019) vs P80002801 (for Q10390)\\n  ☁ Mismatch in identifier__ballotpedia for 96324d91-c6e4-401a-b43e-a526dabe40a8 (John McCain) vs John_McCain (for Q10390)\\n  ☁ Mismatch in identifier__cspan for 96324d91-c6e4-401a-b43e-a526dabe40a8 (7476) vs johnmccain (for Q10390)\\n  ☁ Mismatch in identifier__ballotpedia for 2a078b6c-0f3b-4319-aa4b-6f4d0fe6b80f (Christopher S. Murphy) vs Christopher_S._Murphy (for Q1077594)\\n  ☁ Mismatch in identifier__cspan for 2a078b6c-0f3b-4319-aa4b-6f4d0fe6b80f (1021270) vs christophersmurphy (for Q1077594)\\n  ☁ Mismatch in identifier__ballotpedia for 075be90e-ff5a-445f-a8e9-4d47d90b8f4f (Kamala Harris) vs Kamal ...

# %% [markdown]
# Note the response object's text content is in JSON format. Let's parse it.

# %%
import json

# %%
json_data = json.loads(r.text)

# %%
json_data
# Out:
# [{'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/4142577?',
#    'display_login': 'DouglasCAyers',
#    'gravatar_id': '',
#    'id': 4142577,
#    'login': 'DouglasCAyers',
#    'url': 'https://api.github.com/users/DouglasCAyers'},
#   'created_at': '2018-03-18T05:55:57Z',
#   'id': '7395970984',
#   'payload': {'description': None,
#    'master_branch': 'master',
#    'pusher_type': 'user',
#    'ref': '1.0.0.1',
#    'ref_type': 'tag'},
#   'public': True,
#   'repo': {'id': 125696120,
#    'name': 'DouglasCAyers/sfdx-expense',
#    'url': 'https://api.github.com/repos/DouglasCAyers/sfdx-expense'},
#   'type': 'CreateEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/12693984?',
#    'display_login': 'everypoliticianbot',
#    'gravatar_id': '',
#    'id': 12693984,
#    'login': 'everypoliticianbot',
#    'url': 'https://api.github.com/users/everypoliticianbot'},
#   'created_at': '2018-03-18T05:55:57Z',
#   'id': '7395970983',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/12497298?',
#    'gravatar_id': '',
#    'id': 12497298,
#    'login': 'everypolitician',
#    'url': 'https://api.github.com/orgs/everypolitician'},
#   'payload': {'action': 'opened',
#    'number': 85515,
#    'pull_request': {'_links': {'comments': {'href': 'https://api.github.com/repos/everypolitician/everypolitician-data/issues/85515/comments'},
#      'commits': {'href': 'https://api.github.com/repos/everypolitician/everypolitician-data/pulls/85515/commits'},
#      'html': {'href': 'https://github.com/everypolitician/everypolitician-data/pull/85515'},
#      'issue': {'href': 'https://api.github.com/repos/everypolitician/everypolitician-data/issues/85515'},
#      'review_comment': {'href': 'https://api.github.com/repos/everypolitician/everypolitician-data/pulls/comments{/number}'},
#      'review_comments': {'href': 'https://api.github.com/repos/everypolitician/everypolitician-data/pulls/85515/comments'},
#      'self': {'href': 'https://api.github.com/repos/everypolitician/everypolitician-data/pulls/85515'},
#      'statuses': {'href': 'https://api.github.com/repos/everypolitician/everypolitician-data/statuses/96c651795edafc1d71cfdc2fb9b4f5389edd5e17'}},
#     'additions': 5,
#     'assignee': None,
#     'assignees': [],
#     'author_association': 'OWNER',
#     'base': {'label': 'everypolitician:master',
#      'ref': 'master',
#      'repo': {'archive_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/{archive_format}{/ref}',
#       'archived': False,
#       'assignees_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/assignees{/user}',
#       'blobs_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/git/blobs{/sha}',
#       'branches_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/branches{/branch}',
#       'clone_url': 'https://github.com/everypolitician/everypolitician-data.git',
#       'collaborators_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/collaborators{/collaborator}',
#       'comments_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/comments{/number}',
#       'commits_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/commits{/sha}',
#       'compare_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/compare/{base}...{head}',
#       'contents_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/contents/{+path}',
#       'contributors_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/contributors',
#       'created_at': '2015-04-28T11:10:07Z',
#       'default_branch': 'master',
#       'deployments_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/deployments',
#       'description': "EveryPolitician's core data store",
#       'downloads_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/downloads',
#       'events_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/events',
#       'fork': False,
#       'forks': 16,
#       'forks_count': 16,
#       'forks_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/forks',
#       'full_name': 'everypolitician/everypolitician-data',
#       'git_commits_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/git/commits{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/git/refs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/git/tags{/sha}',
#       'git_url': 'git://github.com/everypolitician/everypolitician-data.git',
#       'has_downloads': True,
#       'has_issues': True,
#       'has_pages': False,
#       'has_projects': True,
#       'has_wiki': False,
#       'homepage': 'http://everypolitician.org/',
#       'hooks_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/hooks',
#       'html_url': 'https://github.com/everypolitician/everypolitician-data',
#       'id': 34725861,
#       'issue_comment_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/issues/comments{/number}',
#       'issue_events_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/issues/events{/number}',
#       'issues_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/issues{/number}',
#       'keys_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/keys{/key_id}',
#       'labels_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/labels{/name}',
#       'language': 'Ruby',
#       'languages_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/languages',
#       'license': None,
#       'merges_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/merges',
#       'milestones_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/milestones{/number}',
#       'mirror_url': None,
#       'name': 'everypolitician-data',
#       'notifications_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/notifications{?since,all,participating}',
#       'open_issues': 532,
#       'open_issues_count': 532,
#       'owner': {'avatar_url': 'https://avatars2.githubusercontent.com/u/12497298?v=4',
#        'events_url': 'https://api.github.com/users/everypolitician/events{/privacy}',
#        'followers_url': 'https://api.github.com/users/everypolitician/followers',
#        'following_url': 'https://api.github.com/users/everypolitician/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/everypolitician/gists{/gist_id}',
#        'gravatar_id': '',
#        'html_url': 'https://github.com/everypolitician',
#        'id': 12497298,
#        'login': 'everypolitician',
#        'organizations_url': 'https://api.github.com/users/everypolitician/orgs',
#        'received_events_url': 'https://api.github.com/users/everypolitician/received_events',
#        'repos_url': 'https://api.github.com/users/everypolitician/repos',
#        'site_admin': False,
#        'starred_url': 'https://api.github.com/users/everypolitician/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/everypolitician/subscriptions',
#        'type': 'Organization',
#        'url': 'https://api.github.com/users/everypolitician'},
#       'private': False,
#       'pulls_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/pulls{/number}',
#       'pushed_at': '2018-03-18T05:55:54Z',
#       'releases_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/releases{/id}',
#       'size': 1742009,
#       'ssh_url': 'git@github.com:everypolitician/everypolitician-data.git',
#       'stargazers_count': 98,
#       'stargazers_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/stargazers',
#       'statuses_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/statuses/{sha}',
#       'subscribers_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/subscribers',
#       'subscription_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/subscription',
#       'svn_url': 'https://github.com/everypolitician/everypolitician-data',
#       'tags_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/tags',
#       'teams_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/teams',
#       'trees_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/git/trees{/sha}',
#       'updated_at': '2018-03-16T12:01:19Z',
#       'url': 'https://api.github.com/repos/everypolitician/everypolitician-data',
#       'watchers': 98,
#       'watchers_count': 98},
#      'sha': 'ffc029acfd37d3a1f0f62391f1b8102ebd9bce7e',
#      'user': {'avatar_url': 'https://avatars2.githubusercontent.com/u/12497298?v=4',
#       'events_url': 'https://api.github.com/users/everypolitician/events{/privacy}',
#       'followers_url': 'https://api.github.com/users/everypolitician/followers',
#       'following_url': 'https://api.github.com/users/everypolitician/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/everypolitician/gists{/gist_id}',
#       'gravatar_id': '',
#       'html_url': 'https://github.com/everypolitician',
#       'id': 12497298,
#       'login': 'everypolitician',
#       'organizations_url': 'https://api.github.com/users/everypolitician/orgs',
#       'received_events_url': 'https://api.github.com/users/everypolitician/received_events',
#       'repos_url': 'https://api.github.com/users/everypolitician/repos',
#       'site_admin': False,
#       'starred_url': 'https://api.github.com/users/everypolitician/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/everypolitician/subscriptions',
#       'type': 'Organization',
#       'url': 'https://api.github.com/users/everypolitician'}},
#     'body': 'Automated refresh of project for United States of America - Senate\n\n#### Output\n\n```\nSwitched to a new branch \'united-states-of-america-senate-1521352177\'\n⤈ No ORDER BY for sources/morph/unitedstates-project.csv\nAdd memberships from sources/morph/unitedstates-project.csv\nMerging with sources/morph/socialmedia.csv\nData Mismatches\n* 499 of 609 unmatched\n\t{:id=>"L000491"}\n\t{:id=>"C001093"}\n\t{:id=>"B001290"}\n\t{:id=>"B001274"}\n\t{:id=>"K000376"}\n\t{:id=>"E000293"}\n\t{:id=>"S001193"}\n\t{:id=>"F000466"}\n\t{:id=>"M001194"}\n\t{:id=>"T000478"}\nMerging with sources/morph/wikidata.csv\nData Mismatches\n  ☁ Mismatch in identifier__fec for 96324d91-c6e4-401a-b43e-a526dabe40a8 (S6AZ00019) vs P80002801 (for Q10390)\n  ☁ Mismatch in identifier__ballotpedia for 96324d91-c6e4-401a-b43e-a526dabe40a8 (John McCain) vs John_McCain (for Q10390)\n  ☁ Mismatch in identifier__cspan for 96324d91-c6e4-401a-b43e-a526dabe40a8 (7476) vs johnmccain (for Q10390)\n  ☁ Mismatch in identifier__ballotpedia for 2a078b6c-0f3b-4319-aa4b-6f4d0fe6b80f (Christopher S. Murphy) vs Christopher_S._Murphy (for Q1077594)\n  ☁ Mismatch in identifier__cspan for 2a078b6c-0f3b-4319-aa4b-6f4d0fe6b80f (1021270) vs christophersmurphy (for Q1077594)\n  ☁ Mismatch in identifier__ballotpedia for 075be90e-ff5a-445f-a8e9-4d47d90b8f4f (Kamala Harris) vs Kamala_Harris (for Q10853588)\n  ☁ Mismatch in identifier__ballotpedia for 7b1f119a-8c22-4f04-b860-cd748cefd1d3 (Cory Booker) vs Cory_Booker (for Q1135767)\n  ☁ Mismatch in identifier__cspan for 7b1f119a-8c22-4f04-b860-cd748cefd1d3 (84679) vs corybooker (for Q1135767)\n  ☁ Mismatch in identifier__ballotpedia for 1673c8f8-146c-4f15-969c-2142308c89cd (Cory Gardner) vs Cory_Gardner (for Q1135774)\n  ☁ Mismatch in identifier__cspan for 1673c8f8-146c-4f15-969c-2142308c89cd (623308) vs corygardner (for Q1135774)\n  ☁ Mismatch in identifier__ballotpedia for ebfb31f5-f5ce-4432-894a-d902e07ab86c (Ed Markey) vs Ed_Markey (for Q1282411)\n  ☁ Mismatch in identifier__cspan for 063bbcb6-b1cb-41d9-b779-86b41d0e19b4 (103) vs johndanforth (for Q1287554)\n  ☁ Mismatch in identifier__ballotpedia for b0dde5ba-e9d6-4ea9-9e2c-876a4d8edc01 (Johnny Isakson) vs Johnny_Isakson (for Q130024)\n  ☁ Mismatch in identifier__ballotpedia for d5f0dd2c-fc84-490c-9413-2a60588b2af2 (John Boozman) vs John_Boozman (for Q1344707)\n  ☁ Mismatch in identifier__cspan for d5f0dd2c-fc84-490c-9413-2a60588b2af2 (92069) vs johnboozman (for Q1344707)\n  ☁ Mismatch in identifier__ballotpedia for 29ddd46b-7096-4bdb-b0cb-21df78097f09 (Jerry Moran) vs Jerry_Moran (for Q1365787)\n  ☁ Mismatch in identifier__ballotpedia for 0338f0ea-52d0-493e-8a21-b9eef903d7d8 (Jeff Merkley) vs Jeff_Merkley (for Q1368405)\n  ☁ Mismatch in identifier__ballotpedia for b70474ad-0b14-4495-8447-be2902dfeda1 (Gary Peters) vs Gary_Peters (for Q1494930)\n  ☁ Mismatch in identifier__ballotpedia for 9ab12ac7-5b24-4cab-9a83-3e7aaf9cd488 (Roy Blunt) vs Roy_Blunt (for Q1525924)\n  ☁ Mismatch in identifier__cspan for 9ab12ac7-5b24-4cab-9a83-3e7aaf9cd488 (45465) vs royblunt (for Q1525924)\n  ☁ Mismatch in identifier__cspan for 8bc79ee9-c992-4556-b534-462780315011 (9266532) vs scottbrown (for Q155125)\n  ☁ Mismatch in identifier__cspan for ca28a62e-aff0-4040-94c7-7be1bf19aed3 (4363) vs josephlieberman (for Q160157)\n  ☁ Mismatch in identifier__cspan for 70b18fa9-4cf1-4d10-ae2e-0f99f6cd23d4 (77429) vs benjaminsasse (for Q16192221)\n  ☁ Mismatch in identifier__ballotpedia for d6655e29-a727-43ec-8b7d-154faf7d3878 (Mazie K. Hirono) vs Mazie_K._Hirono (for Q16476)\n  ☁ Mismatch in birth_date for b7e8d905-4681-450a-b129-dc1e79ab0338 (1955-09-28) vs 1955-09-29 (for Q1691395)\n  ☁ Mismatch in identifier__ballotpedia for b7e8d905-4681-450a-b129-dc1e79ab0338 (Joe Donnelly) vs Joe_Donnelly (for Q1691395)\n  ☁ Mismatch in identifier__ballotpedia for e01cf03e-5cf5-4c66-a0f8-e79de6ddee41 (Brian E. Schatz) vs Brian_E._Schatz (for Q1827902)\n  ☁ Mismatch in identifier__ballotpedia for c1d19c22-316f-486 ...
#     'changed_files': 2,
#     'closed_at': None,
#     'comments': 0,
#     'comments_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/issues/85515/comments',
#     'commits': 1,
#     'commits_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/pulls/85515/commits',
#     'created_at': '2018-03-18T05:55:56Z',
#     'deletions': 1,
#     'diff_url': 'https://github.com/everypolitician/everypolitician-data/pull/85515.diff',
#     'head': {'label': 'everypolitician:united-states-of-america-senate-1521352177',
#      'ref': 'united-states-of-america-senate-1521352177',
#      'repo': {'archive_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/{archive_format}{/ref}',
#       'archived': False,
#       'assignees_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/assignees{/user}',
#       'blobs_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/git/blobs{/sha}',
#       'branches_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/branches{/branch}',
#       'clone_url': 'https://github.com/everypolitician/everypolitician-data.git',
#       'collaborators_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/collaborators{/collaborator}',
#       'comments_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/comments{/number}',
#       'commits_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/commits{/sha}',
#       'compare_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/compare/{base}...{head}',
#       'contents_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/contents/{+path}',
#       'contributors_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/contributors',
#       'created_at': '2015-04-28T11:10:07Z',
#       'default_branch': 'master',
#       'deployments_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/deployments',
#       'description': "EveryPolitician's core data store",
#       'downloads_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/downloads',
#       'events_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/events',
#       'fork': False,
#       'forks': 16,
#       'forks_count': 16,
#       'forks_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/forks',
#       'full_name': 'everypolitician/everypolitician-data',
#       'git_commits_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/git/commits{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/git/refs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/git/tags{/sha}',
#       'git_url': 'git://github.com/everypolitician/everypolitician-data.git',
#       'has_downloads': True,
#       'has_issues': True,
#       'has_pages': False,
#       'has_projects': True,
#       'has_wiki': False,
#       'homepage': 'http://everypolitician.org/',
#       'hooks_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/hooks',
#       'html_url': 'https://github.com/everypolitician/everypolitician-data',
#       'id': 34725861,
#       'issue_comment_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/issues/comments{/number}',
#       'issue_events_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/issues/events{/number}',
#       'issues_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/issues{/number}',
#       'keys_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/keys{/key_id}',
#       'labels_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/labels{/name}',
#       'language': 'Ruby',
#       'languages_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/languages',
#       'license': None,
#       'merges_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/merges',
#       'milestones_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/milestones{/number}',
#       'mirror_url': None,
#       'name': 'everypolitician-data',
#       'notifications_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/notifications{?since,all,participating}',
#       'open_issues': 532,
#       'open_issues_count': 532,
#       'owner': {'avatar_url': 'https://avatars2.githubusercontent.com/u/12497298?v=4',
#        'events_url': 'https://api.github.com/users/everypolitician/events{/privacy}',
#        'followers_url': 'https://api.github.com/users/everypolitician/followers',
#        'following_url': 'https://api.github.com/users/everypolitician/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/everypolitician/gists{/gist_id}',
#        'gravatar_id': '',
#        'html_url': 'https://github.com/everypolitician',
#        'id': 12497298,
#        'login': 'everypolitician',
#        'organizations_url': 'https://api.github.com/users/everypolitician/orgs',
#        'received_events_url': 'https://api.github.com/users/everypolitician/received_events',
#        'repos_url': 'https://api.github.com/users/everypolitician/repos',
#        'site_admin': False,
#        'starred_url': 'https://api.github.com/users/everypolitician/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/everypolitician/subscriptions',
#        'type': 'Organization',
#        'url': 'https://api.github.com/users/everypolitician'},
#       'private': False,
#       'pulls_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/pulls{/number}',
#       'pushed_at': '2018-03-18T05:55:54Z',
#       'releases_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/releases{/id}',
#       'size': 1742009,
#       'ssh_url': 'git@github.com:everypolitician/everypolitician-data.git',
#       'stargazers_count': 98,
#       'stargazers_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/stargazers',
#       'statuses_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/statuses/{sha}',
#       'subscribers_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/subscribers',
#       'subscription_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/subscription',
#       'svn_url': 'https://github.com/everypolitician/everypolitician-data',
#       'tags_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/tags',
#       'teams_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/teams',
#       'trees_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/git/trees{/sha}',
#       'updated_at': '2018-03-16T12:01:19Z',
#       'url': 'https://api.github.com/repos/everypolitician/everypolitician-data',
#       'watchers': 98,
#       'watchers_count': 98},
#      'sha': '96c651795edafc1d71cfdc2fb9b4f5389edd5e17',
#      'user': {'avatar_url': 'https://avatars2.githubusercontent.com/u/12497298?v=4',
#       'events_url': 'https://api.github.com/users/everypolitician/events{/privacy}',
#       'followers_url': 'https://api.github.com/users/everypolitician/followers',
#       'following_url': 'https://api.github.com/users/everypolitician/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/everypolitician/gists{/gist_id}',
#       'gravatar_id': '',
#       'html_url': 'https://github.com/everypolitician',
#       'id': 12497298,
#       'login': 'everypolitician',
#       'organizations_url': 'https://api.github.com/users/everypolitician/orgs',
#       'received_events_url': 'https://api.github.com/users/everypolitician/received_events',
#       'repos_url': 'https://api.github.com/users/everypolitician/repos',
#       'site_admin': False,
#       'starred_url': 'https://api.github.com/users/everypolitician/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/everypolitician/subscriptions',
#       'type': 'Organization',
#       'url': 'https://api.github.com/users/everypolitician'}},
#     'html_url': 'https://github.com/everypolitician/everypolitician-data/pull/85515',
#     'id': 175736716,
#     'issue_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/issues/85515',
#     'labels': [],
#     'locked': False,
#     'maintainer_can_modify': False,
#     'merge_commit_sha': None,
#     'mergeable': None,
#     'mergeable_state': 'unknown',
#     'merged': False,
#     'merged_at': None,
#     'merged_by': None,
#     'milestone': None,
#     'number': 85515,
#     'patch_url': 'https://github.com/everypolitician/everypolitician-data/pull/85515.patch',
#     'rebaseable': None,
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'review_comment_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/pulls/comments{/number}',
#     'review_comments': 0,
#     'review_comments_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/pulls/85515/comments',
#     'state': 'open',
#     'statuses_url': 'https://api.github.com/repos/everypolitician/everypolitician-data/statuses/96c651795edafc1d71cfdc2fb9b4f5389edd5e17',
#     'title': 'United States of America (Senate): refresh project',
#     'updated_at': '2018-03-18T05:55:56Z',
#     'url': 'https://api.github.com/repos/everypolitician/everypolitician-data/pulls/85515',
#     'user': {'avatar_url': 'https://avatars3.githubusercontent.com/u/12693984?v=4',
#      'events_url': 'https://api.github.com/users/everypoliticianbot/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/everypoliticianbot/followers',
#      'following_url': 'https://api.github.com/users/everypoliticianbot/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/everypoliticianbot/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/everypoliticianbot',
#      'id': 12693984,
#      'login': 'everypoliticianbot',
#      'organizations_url': 'https://api.github.com/users/everypoliticianbot/orgs',
#      'received_events_url': 'https://api.github.com/users/everypoliticianbot/received_events',
#      'repos_url': 'https://api.github.com/users/everypoliticianbot/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/everypoliticianbot/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/everypoliticianbot/subscriptions',
#      'type': 'User',
#      'url': 'https://api.github.com/users/everypoliticianbot'}}},
#   'public': True,
#   'repo': {'id': 34725861,
#    'name': 'everypolitician/everypolitician-data',
#    'url': 'https://api.github.com/repos/everypolitician/everypolitician-data'},
#   'type': 'PullRequestEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/22828368?',
#    'display_login': 'laippmiles',
#    'gravatar_id': '',
#    'id': 22828368,
#    'login': 'laippmiles',
#    'url': 'https://api.github.com/users/laippmiles'},
#   'created_at': '2018-03-18T05:55:57Z',
#   'id': '7395970981',
#   'payload': {'before': 'd79128573f0c68fe775aabffbcce151f9cf6c5f8',
#    'commits': [{'author': {'email': 'laippmiles@gmail.com',
#       'name': 'laipp123'},
#      'distinct': True,
#      'message': 'ELM',
#      'sha': 'fa0587fa3c4a09bd2941e7483dac9e832820b898',
#      'url': 'https://api.github.com/repos/laippmiles/ELM/commits/fa0587fa3c4a09bd2941e7483dac9e832820b898'}],
#    'distinct_size': 1,
#    'head': 'fa0587fa3c4a09bd2941e7483dac9e832820b898',
#    'push_id': 2411693037,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 124390890,
#    'name': 'laippmiles/ELM',
#    'url': 'https://api.github.com/repos/laippmiles/ELM'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/4142577?',
#    'display_login': 'DouglasCAyers',
#    'gravatar_id': '',
#    'id': 4142577,
#    'login': 'DouglasCAyers',
#    'url': 'https://api.github.com/users/DouglasCAyers'},
#   'created_at': '2018-03-18T05:55:57Z',
#   'id': '7395970980',
#   'payload': {'action': 'published',
#    'release': {'assets': [],
#     'assets_url': 'https://api.github.com/repos/DouglasCAyers/sfdx-expense/releases/10138673/assets',
#     'author': {'avatar_url': 'https://avatars1.githubusercontent.com/u/4142577?v=4',
#      'events_url': 'https://api.github.com/users/DouglasCAyers/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/DouglasCAyers/followers',
#      'following_url': 'https://api.github.com/users/DouglasCAyers/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/DouglasCAyers/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/DouglasCAyers',
#      'id': 4142577,
#      'login': 'DouglasCAyers',
#      'organizations_url': 'https://api.github.com/users/DouglasCAyers/orgs',
#      'received_events_url': 'https://api.github.com/users/DouglasCAyers/received_events',
#      'repos_url': 'https://api.github.com/users/DouglasCAyers/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/DouglasCAyers/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/DouglasCAyers/subscriptions',
#      'type': 'User',
#      'url': 'https://api.github.com/users/DouglasCAyers'},
#     'body': '',
#     'created_at': '2018-03-18T05:46:11Z',
#     'draft': False,
#     'html_url': 'https://github.com/DouglasCAyers/sfdx-expense/releases/tag/1.0.0.1',
#     'id': 10138673,
#     'name': '',
#     'prerelease': False,
#     'published_at': '2018-03-18T05:55:56Z',
#     'tag_name': '1.0.0.1',
#     'tarball_url': 'https://api.github.com/repos/DouglasCAyers/sfdx-expense/tarball/1.0.0.1',
#     'target_commitish': 'master',
#     'upload_url': 'https://uploads.github.com/repos/DouglasCAyers/sfdx-expense/releases/10138673/assets{?name,label}',
#     'url': 'https://api.github.com/repos/DouglasCAyers/sfdx-expense/releases/10138673',
#     'zipball_url': 'https://api.github.com/repos/DouglasCAyers/sfdx-expense/zipball/1.0.0.1'}},
#   'public': True,
#   'repo': {'id': 125696120,
#    'name': 'DouglasCAyers/sfdx-expense',
#    'url': 'https://api.github.com/repos/DouglasCAyers/sfdx-expense'},
#   'type': 'ReleaseEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/34978541?',
#    'display_login': 'chenghehe',
#    'gravatar_id': '',
#    'id': 34978541,
#    'login': 'chenghehe',
#    'url': 'https://api.github.com/users/chenghehe'},
#   'created_at': '2018-03-18T05:55:56Z',
#   'id': '7395970979',
#   'payload': {'description': '练习呵呵',
#    'master_branch': 'master',
#    'pusher_type': 'user',
#    'ref': '成呵呵',
#    'ref_type': 'branch'},
#   'public': True,
#   'repo': {'id': 125696855,
#    'name': 'chenghehe/-',
#    'url': 'https://api.github.com/repos/chenghehe/-'},
#   'type': 'CreateEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/19980290?',
#    'display_login': 'DyingEcho',
#    'gravatar_id': '',
#    'id': 19980290,
#    'login': 'DyingEcho',
#    'url': 'https://api.github.com/users/DyingEcho'},
#   'created_at': '2018-03-18T05:55:56Z',
#   'id': '7395970973',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/24627166?',
#    'gravatar_id': '',
#    'id': 24627166,
#    'login': 'ISD-Sound-and-Lights',
#    'url': 'https://api.github.com/orgs/ISD-Sound-and-Lights'},
#   'payload': {'action': 'created',
#    'comment': {'author_association': 'CONTRIBUTOR',
#     'body': "So far, I have this:\r\n\r\n```\r\nsyNMNdyo/::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::s\r\nmMMMMMMMNmhs+:.`                                                                                   /\r\nymMMMMMMMMMMMMNNdyo/-`                                                                             /\r\n/`:+sydNMMMMMMMMMMMMNNdyo/.                                                                        /\r\n/     ``.:+shmNMMMMMMMMMMMNmhs/-`                                                                  /\r\n/            ``-/oydNMMMMMMMMMMNmho:.                                                              /\r\n/                  `.-/shmMMMMMMMMMMNds/.                                                          /\r\n/                        `.:ohmMMMMMMMMMNds/.                                                      /\r\n/                             `./sdNMMMMMMMMNdo:`                                                  /\r\n/                                 `.:ohNMMMMMMMNmy/.                                               /\r\n/                                     `.:sdNMMMMMMMNh+-                                            /\r\n/                                         `./ymMMMMMMMNdo-`                                        /\r\n/                                             `:sdNMMMMMMNdyhddddmmmdddhhyyso+:-.`                 /\r\n/                                                `/NMMMMMMMMMMMMMMMMMMMMMMMMMMMNNdy/`              /\r\n/                                                -mMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMh.             /\r\n/                                                hMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMy             /\r\n/                                               `NMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMN`            /\r\n/                                               .MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMM-            /\r\n/      ___                   _      _           .MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMM-            /\r\n/     | ___  _ ___ _ __ __ _| |_ __| |_          NMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMN`            /\r\n/     | _| || / -_| '_ / _` |  _/ _| ' \\         sMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMh             /\r\n/     |___\\_, \\___| .__\\__,_|\\__\\__|_||_|        .NMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMN-             /\r\n/         |__/    |_|                             /NMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMM+              /\r\n/                                                  +NMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMN:              /\r\n/                                                   :dMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMNs`            /\r\n/                                                    `/dNMMMMMMMMMMMMMMMMMMMMMNdNMMMMMd:           /\r\n/                                                      `-odNMMMMMMMMMMMMMMMNdo- .hMMMMMNo`         /\r\n/                                                          .:+yhdmmNNmmdho/-     `+NMMMMMh.        /\r\n/                                                                ``..``            -dMMMMMm:       /\r\n/                                                                                   `sMMMMMNo`     /\r\n/                                                                                     +NMMMMMy`    /\r\n/                                                                                      -dMMMMMd-   /\r\n/                                                                                       `hMMMMMm:  /\r\n/                                                                                        `sMMMMMN/ /\r\n/                                                                                          +NMMMMM+/\r\n/                                                                                           /NMMMMMh\r\n/                                                                                            /NMMMMN\r\ns:::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::smMN ...
#     'created_at': '2018-03-18T05:55:56Z',
#     'html_url': 'https://github.com/ISD-Sound-and-Lights/eyepatch/issues/3#issuecomment-373974957',
#     'id': 373974957,
#     'issue_url': 'https://api.github.com/repos/ISD-Sound-and-Lights/eyepatch/issues/3',
#     'updated_at': '2018-03-18T05:55:56Z',
#     'url': 'https://api.github.com/repos/ISD-Sound-and-Lights/eyepatch/issues/comments/373974957',
#     'user': {'avatar_url': 'https://avatars1.githubusercontent.com/u/19980290?v=4',
#      'events_url': 'https://api.github.com/users/DyingEcho/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/DyingEcho/followers',
#      'following_url': 'https://api.github.com/users/DyingEcho/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/DyingEcho/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/DyingEcho',
#      'id': 19980290,
#      'login': 'DyingEcho',
#      'organizations_url': 'https://api.github.com/users/DyingEcho/orgs',
#      'received_events_url': 'https://api.github.com/users/DyingEcho/received_events',
#      'repos_url': 'https://api.github.com/users/DyingEcho/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/DyingEcho/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/DyingEcho/subscriptions',
#      'type': 'User',
#      'url': 'https://api.github.com/users/DyingEcho'}},
#    'issue': {'assignee': {'avatar_url': 'https://avatars1.githubusercontent.com/u/19980290?v=4',
#      'events_url': 'https://api.github.com/users/DyingEcho/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/DyingEcho/followers',
#      'following_url': 'https://api.github.com/users/DyingEcho/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/DyingEcho/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/DyingEcho',
#      'id': 19980290,
#      'login': 'DyingEcho',
#      'organizations_url': 'https://api.github.com/users/DyingEcho/orgs',
#      'received_events_url': 'https://api.github.com/users/DyingEcho/received_events',
#      'repos_url': 'https://api.github.com/users/DyingEcho/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/DyingEcho/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/DyingEcho/subscriptions',
#      'type': 'User',
#      'url': 'https://api.github.com/users/DyingEcho'},
#     'assignees': [{'avatar_url': 'https://avatars1.githubusercontent.com/u/19980290?v=4',
#       'events_url': 'https://api.github.com/users/DyingEcho/events{/privacy}',
#       'followers_url': 'https://api.github.com/users/DyingEcho/followers',
#       'following_url': 'https://api.github.com/users/DyingEcho/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/DyingEcho/gists{/gist_id}',
#       'gravatar_id': '',
#       'html_url': 'https://github.com/DyingEcho',
#       'id': 19980290,
#       'login': 'DyingEcho',
#       'organizations_url': 'https://api.github.com/users/DyingEcho/orgs',
#       'received_events_url': 'https://api.github.com/users/DyingEcho/received_events',
#       'repos_url': 'https://api.github.com/users/DyingEcho/repos',
#       'site_admin': False,
#       'starred_url': 'https://api.github.com/users/DyingEcho/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/DyingEcho/subscriptions',
#       'type': 'User',
#       'url': 'https://api.github.com/users/DyingEcho'}],
#     'author_association': 'CONTRIBUTOR',
#     'body': '',
#     'closed_at': None,
#     'comments': 0,
#     'comments_url': 'https://api.github.com/repos/ISD-Sound-and-Lights/eyepatch/issues/3/comments',
#     'created_at': '2018-03-17T21:52:39Z',
#     'events_url': 'https://api.github.com/repos/ISD-Sound-and-Lights/eyepatch/issues/3/events',
#     'html_url': 'https://github.com/ISD-Sound-and-Lights/eyepatch/issues/3',
#     'id': 306193618,
#     'labels': [],
#     'labels_url': 'https://api.github.com/repos/ISD-Sound-and-Lights/eyepatch/issues/3/labels{/name}',
#     'locked': False,
#     'milestone': None,
#     'number': 3,
#     'repository_url': 'https://api.github.com/repos/ISD-Sound-and-Lights/eyepatch',
#     'state': 'open',
#     'title': 'Add Banner',
#     'updated_at': '2018-03-18T05:55:56Z',
#     'url': 'https://api.github.com/repos/ISD-Sound-and-Lights/eyepatch/issues/3',
#     'user': {'avatar_url': 'https://avatars0.githubusercontent.com/u/14109217?v=4',
#      'events_url': 'https://api.github.com/users/il8677/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/il8677/followers',
#      'following_url': 'https://api.github.com/users/il8677/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/il8677/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/il8677',
#      'id': 14109217,
#      'login': 'il8677',
#      'organizations_url': 'https://api.github.com/users/il8677/orgs',
#      'received_events_url': 'https://api.github.com/users/il8677/received_events',
#      'repos_url': 'https://api.github.com/users/il8677/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/il8677/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/il8677/subscriptions',
#      'type': 'User',
#      'url': 'https://api.github.com/users/il8677'}}},
#   'public': True,
#   'repo': {'id': 125650385,
#    'name': 'ISD-Sound-and-Lights/eyepatch',
#    'url': 'https://api.github.com/repos/ISD-Sound-and-Lights/eyepatch'},
#   'type': 'IssueCommentEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/33500718?',
#    'display_login': 'dipper-github-icn-bom-cdg',
#    'gravatar_id': '',
#    'id': 33500718,
#    'login': 'dipper-github-icn-bom-cdg',
#    'url': 'https://api.github.com/users/dipper-github-icn-bom-cdg'},
#   'created_at': '2018-03-18T05:55:56Z',
#   'id': '7395970971',
#   'payload': {'description': None,
#    'master_branch': 'master',
#    'pusher_type': 'user',
#    'ref': 'canary-test-3a78f9d7-6e8d-410b-b1f5-4314d6b2104f',
#    'ref_type': 'branch'},
#   'public': True,
#   'repo': {'id': 112368276,
#    'name': 'dipper-github-icn-bom-cdg/test-python-sample',
#    'url': 'https://api.github.com/repos/dipper-github-icn-bom-cdg/test-python-sample'},
#   'type': 'CreateEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/15185258?',
#    'display_login': 'jeffreymeng',
#    'gravatar_id': '',
#    'id': 15185258,
#    'login': 'jeffreymeng',
#    'url': 'https://api.github.com/users/jeffreymeng'},
#   'created_at': '2018-03-18T05:55:56Z',
#   'id': '7395970968',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/23644893?',
#    'gravatar_id': '',
#    'id': 23644893,
#    'login': 't485',
#    'url': 'https://api.github.com/orgs/t485'},
#   'payload': {'before': '0665dbd2cb36962d3776067f8f41602fe8410b66',
#    'commits': [{'author': {'email': 'jeffkmeng@gmail.com',
#       'name': 'Jeffrey Meng'},
#      'distinct': True,
#      'message': 'update files',
#      'sha': '4418a327b910b4b835b337b6978a020c9b5a1c75',
#      'url': 'https://api.github.com/repos/t485/t485/commits/4418a327b910b4b835b337b6978a020c9b5a1c75'}],
#    'distinct_size': 1,
#    'head': '4418a327b910b4b835b337b6978a020c9b5a1c75',
#    'push_id': 2411693029,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 39268251,
#    'name': 't485/t485',
#    'url': 'https://api.github.com/repos/t485/t485'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/12016607?',
#    'display_login': '4artit',
#    'gravatar_id': '',
#    'id': 12016607,
#    'login': '4artit',
#    'url': 'https://api.github.com/users/4artit'},
#   'created_at': '2018-03-18T05:55:56Z',
#   'id': '7395970967',
#   'payload': {'before': 'fb5ee9d57803773dea3550b3732a5fc9964798ed',
#    'commits': [{'author': {'email': '4artit@gmail.com', 'name': 'Dongmin Kim'},
#      'distinct': True,
#      'message': 'Delete project_output.mp4',
#      'sha': '0120183efd0ec5483c508913f8291d69af0ce36d',
#      'url': 'https://api.github.com/repos/4artit/CARND_Term1_Vehicle-Detection/commits/0120183efd0ec5483c508913f8291d69af0ce36d'}],
#    'distinct_size': 1,
#    'head': '0120183efd0ec5483c508913f8291d69af0ce36d',
#    'push_id': 2411693026,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 85483872,
#    'name': '4artit/CARND_Term1_Vehicle-Detection',
#    'url': 'https://api.github.com/repos/4artit/CARND_Term1_Vehicle-Detection'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/15869383?',
#    'display_login': 'accelsao',
#    'gravatar_id': '',
#    'id': 15869383,
#    'login': 'accelsao',
#    'url': 'https://api.github.com/users/accelsao'},
#   'created_at': '2018-03-18T05:55:55Z',
#   'id': '7395970965',
#   'payload': {'before': 'db5be3c1815d2a9ec3430410513cf968797db339',
#    'commits': [{'author': {'email': 'jay70550@yahoo.com.tw',
#       'name': 'ジブリール-Jiburiru'},
#      'distinct': True,
#      'message': 'Update _config.yml',
#      'sha': 'aad0bf0570e45c1f05bdcc937b117d549d8aba74',
#      'url': 'https://api.github.com/repos/accelsao/accelsao.github.io/commits/aad0bf0570e45c1f05bdcc937b117d549d8aba74'}],
#    'distinct_size': 1,
#    'head': 'aad0bf0570e45c1f05bdcc937b117d549d8aba74',
#    'push_id': 2411693025,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 123791379,
#    'name': 'accelsao/accelsao.github.io',
#    'url': 'https://api.github.com/repos/accelsao/accelsao.github.io'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/6619961?',
#    'display_login': 'coreyjadams',
#    'gravatar_id': '',
#    'id': 6619961,
#    'login': 'coreyjadams',
#    'url': 'https://api.github.com/users/coreyjadams'},
#   'created_at': '2018-03-18T05:55:55Z',
#   'id': '7395970963',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/35508534?',
#    'gravatar_id': '',
#    'id': 35508534,
#    'login': 'Harvard-Production',
#    'url': 'https://api.github.com/orgs/Harvard-Production'},
#   'payload': {'before': '3738f1253065914b1a8ab47461be7d3e5cff794d',
#    'commits': [{'author': {'email': 'coreyjadams@gmail.com',
#       'name': 'Corey Adams'},
#      'distinct': True,
#      'message': 'Update datasets Sun Mar 18 01:55:49 EDT 2018',
#      'sha': '242f98d7fa67e4297b62972c67e01c6b6f19f407',
#      'url': 'https://api.github.com/repos/Harvard-Production/Harvard-Production.github.io/commits/242f98d7fa67e4297b62972c67e01c6b6f19f407'}],
#    'distinct_size': 1,
#    'head': '242f98d7fa67e4297b62972c67e01c6b6f19f407',
#    'push_id': 2411693023,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 124944492,
#    'name': 'Harvard-Production/Harvard-Production.github.io',
#    'url': 'https://api.github.com/repos/Harvard-Production/Harvard-Production.github.io'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/12693984?',
#    'display_login': 'everypoliticianbot',
#    'gravatar_id': '',
#    'id': 12693984,
#    'login': 'everypoliticianbot',
#    'url': 'https://api.github.com/users/everypoliticianbot'},
#   'created_at': '2018-03-18T05:55:55Z',
#   'id': '7395970960',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/18443033?',
#    'gravatar_id': '',
#    'id': 18443033,
#    'login': 'everypolitician-scrapers',
#    'url': 'https://api.github.com/orgs/everypolitician-scrapers'},
#   'payload': {'before': 'c70e47945067aceebbf4ccec03cf816f54fa8b7a',
#    'commits': [{'author': {'email': 'scraped_page_archive-0.5.0@scrapers.everypolitician.org',
#       'name': 'scraped_page_archive gem 0.5.0'},
#      'distinct': True,
#      'message': '200 OK http://sitl.diputados.gob.mx/LXIII_leg/curricula.php?dipt=442',
#      'sha': '4459142ce9ac9af144852543baf649d0690c3a80',
#      'url': 'https://api.github.com/repos/everypolitician-scrapers/mexico-diputados-2015/commits/4459142ce9ac9af144852543baf649d0690c3a80'}],
#    'distinct_size': 1,
#    'head': '4459142ce9ac9af144852543baf649d0690c3a80',
#    'push_id': 2411693022,
#    'ref': 'refs/heads/scraped-pages-archive',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 42112589,
#    'name': 'everypolitician-scrapers/mexico-diputados-2015',
#    'url': 'https://api.github.com/repos/everypolitician-scrapers/mexico-diputados-2015'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/22550617?',
#    'display_login': 'jgjin',
#    'gravatar_id': '',
#    'id': 22550617,
#    'login': 'jgjin',
#    'url': 'https://api.github.com/users/jgjin'},
#   'created_at': '2018-03-18T05:55:55Z',
#   'id': '7395970956',
#   'payload': {'before': '6c37ad08fc4f6d374c7ab3d735fe66df92848397',
#    'commits': [{'author': {'email': 'jgjin@umich.edu', 'name': 'jason-banana'},
#      'distinct': True,
#      'message': 'Changed hydras and added org agenda stuff',
#      'sha': 'f92b0d663f02152f3c41d144e753f60d836d1cc0',
#      'url': 'https://api.github.com/repos/jgjin/init.el/commits/f92b0d663f02152f3c41d144e753f60d836d1cc0'}],
#    'distinct_size': 1,
#    'head': 'f92b0d663f02152f3c41d144e753f60d836d1cc0',
#    'push_id': 2411693018,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 90656852,
#    'name': 'jgjin/init.el',
#    'url': 'https://api.github.com/repos/jgjin/init.el'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/36736841?',
#    'display_login': 'aziz-aljawad',
#    'gravatar_id': '',
#    'id': 36736841,
#    'login': 'aziz-aljawad',
#    'url': 'https://api.github.com/users/aziz-aljawad'},
#   'created_at': '2018-03-18T05:55:55Z',
#   'id': '7395970955',
#   'payload': {'description': 'A prototype pet shop app with Ionic 01',
#    'master_branch': 'master',
#    'pusher_type': 'user',
#    'ref': 'master',
#    'ref_type': 'branch'},
#   'public': True,
#   'repo': {'id': 125696166,
#    'name': 'aziz-aljawad/PetShopApp',
#    'url': 'https://api.github.com/repos/aziz-aljawad/PetShopApp'},
#   'type': 'CreateEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'id': 8517910,
#    'login': 'LombiqBot',
#    'url': 'https://api.github.com/users/LombiqBot'},
#   'created_at': '2018-03-18T05:55:55Z',
#   'id': '7395970954',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?',
#    'gravatar_id': '',
#    'id': 8158177,
#    'login': 'Lombiq',
#    'url': 'https://api.github.com/orgs/Lombiq'},
#   'payload': {'before': 'bff84b7597a26b5bcc041fcfabd8f353c8565b9d',
#    'commits': [],
#    'distinct_size': 0,
#    'head': 'bff84b7597a26b5bcc041fcfabd8f353c8565b9d',
#    'push_id': 2411693015,
#    'ref': 'refs/heads/issue/BTLR-63',
#    'size': 0},
#   'public': True,
#   'repo': {'id': 46623531,
#    'name': 'Lombiq/Orchard-Antispam',
#    'url': 'https://api.github.com/repos/Lombiq/Orchard-Antispam'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/1489143?',
# ...
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/jgkamat/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/jgkamat/subscriptions',
#      'type': 'User',
#      'url': 'https://api.github.com/users/jgkamat'}}},
#   'public': True,
#   'repo': {'id': 25669551,
#    'name': 'jgkamat/jgkamat.github.io',
#    'url': 'https://api.github.com/repos/jgkamat/jgkamat.github.io'},
#   'type': 'IssueCommentEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/16862201?',
#    'display_login': 'HackSoul',
#    'gravatar_id': '',
#    'id': 16862201,
#    'login': 'HackSoul',
#    'url': 'https://api.github.com/users/HackSoul'},
#   'created_at': '2018-03-18T05:55:54Z',
#   'id': '7395970944',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/32198232?',
#    'gravatar_id': '',
#    'id': 32198232,
#    'login': 'flutter-dev',
#    'url': 'https://api.github.com/orgs/flutter-dev'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'repo': {'id': 123717357,
#    'name': 'flutter-dev/website',
#    'url': 'https://api.github.com/repos/flutter-dev/website'},
#   'type': 'WatchEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/32840933?',
#    'display_login': 'mykarl',
#    'gravatar_id': '',
#    'id': 32840933,
#    'login': 'mykarl',
#    'url': 'https://api.github.com/users/mykarl'},
#   'created_at': '2018-03-18T05:55:54Z',
#   'id': '7395970941',
#   'payload': {'description': 'Converts (basic) Python3 input as a Perl file',
#    'master_branch': 'master',
#    'pusher_type': 'user',
#    'ref': None,
#    'ref_type': 'repository'},
#   'public': True,
#   'repo': {'id': 125696893,
#    'name': 'mykarl/python-to-perl',
#    'url': 'https://api.github.com/repos/mykarl/python-to-perl'},
#   'type': 'CreateEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/36457340?',
#    'display_login': 'Dwy0202',
#    'gravatar_id': '',
#    'id': 36457340,
#    'login': 'Dwy0202',
#    'url': 'https://api.github.com/users/Dwy0202'},
#   'created_at': '2018-03-18T05:55:54Z',
#   'id': '7395970940',
#   'payload': {'description': None,
#    'master_branch': 'master',
#    'pusher_type': 'user',
#    'ref': None,
#    'ref_type': 'repository'},
#   'public': True,
#   'repo': {'id': 125696892,
#    'name': 'Dwy0202/Quiz',
#    'url': 'https://api.github.com/repos/Dwy0202/Quiz'},
#   'type': 'CreateEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/36158258?',
#    'display_login': 'mhmdyasr',
#    'gravatar_id': '',
#    'id': 36158258,
#    'login': 'mhmdyasr',
#    'url': 'https://api.github.com/users/mhmdyasr'},
#   'created_at': '2018-03-18T05:55:54Z',
#   'id': '7395970938',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/5671847?',
#    'gravatar_id': '',
#    'id': 5671847,
#    'login': 'hansonrobotics',
#    'url': 'https://api.github.com/orgs/hansonrobotics'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'repo': {'id': 85795575,
#    'name': 'hansonrobotics/hangouts_ros_automation',
#    'url': 'https://api.github.com/repos/hansonrobotics/hangouts_ros_automation'},
#   'type': 'WatchEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/37490387?',
#    'display_login': 'fadelnavi',
#    'gravatar_id': '',
#    'id': 37490387,
#    'login': 'fadelnavi',
#    'url': 'https://api.github.com/users/fadelnavi'},
#   'created_at': '2018-03-18T05:55:54Z',
#   'id': '7395970937',
#   'payload': {'before': 'e409197a4abff3d465287ead870f7193383ec79e',
#    'commits': [{'author': {'email': '37490387+fadelnavi@users.noreply.github.com',
#       'name': 'fadelnavi'},
#      'distinct': True,
#      'message': 'Create customsafelink.js',
#      'sha': '084b1daac87dc566a3b77d6949c1d5d5f08932ac',
#      'url': 'https://api.github.com/repos/fadelnavi/safelink/commits/084b1daac87dc566a3b77d6949c1d5d5f08932ac'}],
#    'distinct_size': 1,
#    'head': '084b1daac87dc566a3b77d6949c1d5d5f08932ac',
#    'push_id': 2411693010,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 125681824,
#    'name': 'fadelnavi/safelink',
#    'url': 'https://api.github.com/repos/fadelnavi/safelink'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/19483035?',
#    'display_login': 'kinoftaiji',
#    'gravatar_id': '',
#    'id': 19483035,
#    'login': 'kinoftaiji',
#    'url': 'https://api.github.com/users/kinoftaiji'},
#   'created_at': '2018-03-18T05:55:53Z',
#   'id': '7395970936',
#   'payload': {'before': 'd381efdb74ee817e55f5d5c685156e31839e066b',
#    'commits': [{'author': {'email': '912504432@qq.com', 'name': 'fanzhen'},
#      'distinct': True,
#      'message': 'openid',
#      'sha': '917f458308ca93fe9ea76abe6ea2d5b6b6099493',
#      'url': 'https://api.github.com/repos/kinoftaiji/code/commits/917f458308ca93fe9ea76abe6ea2d5b6b6099493'}],
#    'distinct_size': 1,
#    'head': '917f458308ca93fe9ea76abe6ea2d5b6b6099493',
#    'push_id': 2411693009,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 91298431,
#    'name': 'kinoftaiji/code',
#    'url': 'https://api.github.com/repos/kinoftaiji/code'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/29916481?',
#    'display_login': 'AshishProdian',
#    'gravatar_id': '',
#    'id': 29916481,
#    'login': 'AshishProdian',
#    'url': 'https://api.github.com/users/AshishProdian'},
#   'created_at': '2018-03-18T05:55:53Z',
#   'id': '7395970935',
#   'payload': {'description': 'only for learn',
#    'master_branch': 'master',
#    'pusher_type': 'user',
#    'ref': 'develop',
#    'ref_type': 'branch'},
#   'public': True,
#   'repo': {'id': 125696869,
#    'name': 'AshishProdian/angular5test',
#    'url': 'https://api.github.com/repos/AshishProdian/angular5test'},
#   'type': 'CreateEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/35956327?',
#    'display_login': 'aswinps10',
#    'gravatar_id': '',
#    'id': 35956327,
#    'login': 'aswinps10',
#    'url': 'https://api.github.com/users/aswinps10'},
#   'created_at': '2018-03-18T05:55:53Z',
#   'id': '7395970934',
#   'payload': {'before': 'fe0d628da71d3a83056edfa94a9b28722b41591b',
#    'commits': [{'author': {'email': '35956327+aswinps10@users.noreply.github.com',
#       'name': 'aswinps10'},
#      'distinct': True,
#      'message': 'Delete sgpas1.txt',
#      'sha': '8c78c1e92485d2969425fd0076c6f58072488ae2',
#      'url': 'https://api.github.com/repos/aswinps10/fosslab/commits/8c78c1e92485d2969425fd0076c6f58072488ae2'}],
#    'distinct_size': 1,
#    'head': '8c78c1e92485d2969425fd0076c6f58072488ae2',
#    'push_id': 2411693007,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 119522360,
#    'name': 'aswinps10/fosslab',
#    'url': 'https://api.github.com/repos/aswinps10/fosslab'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/395096?',
#    'display_login': 'prsolucoes',
#    'gravatar_id': '',
#    'id': 395096,
#    'login': 'prsolucoes',
#    'url': 'https://api.github.com/users/prsolucoes'},
#   'created_at': '2018-03-18T05:55:53Z',
#   'id': '7395970933',
#   'payload': {'before': '561cac005bb8da36d2eb5fbbddeb1d5363b9427b',
#    'commits': [{'author': {'email': 'paulo@prsolucoes.com',
#       'name': 'Paulo Coutinho'},
#      'distinct': True,
#      'message': 'fix for navbar background color after update bulma',
#      'sha': '314900f54ed1db12b054788c8f52ef724e6f2431',
#      'url': 'https://api.github.com/repos/prsolucoes/gohc-web-app/commits/314900f54ed1db12b054788c8f52ef724e6f2431'}],
#    'distinct_size': 1,
#    'head': '314900f54ed1db12b054788c8f52ef724e6f2431',
#    'push_id': 2411693006,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 73601097,
#    'name': 'prsolucoes/gohc-web-app',
#    'url': 'https://api.github.com/repos/prsolucoes/gohc-web-app'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/35348235?',
#    'display_login': 'myapplestory',
#    'gravatar_id': '',
#    'id': 35348235,
#    'login': 'myapplestory',
#    'url': 'https://api.github.com/users/myapplestory'},
#   'created_at': '2018-03-18T05:55:53Z',
#   'id': '7395970929',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/36286607?',
#    'gravatar_id': '',
#    'id': 36286607,
#    'login': 'CMPUT301W18T05',
#    'url': 'https://api.github.com/orgs/CMPUT301W18T05'},
#   'payload': {'before': 'eb00d496843cc0c926d110e8e7bbf83269c91c02',
#    'commits': [{'author': {'email': 'csun@ualberta.ca',
#       'name': 'myapplestory'},
#      'distinct': True,
#      'message': 'almost able to demove lower bid',
#      'sha': 'ef0949edc619700882a741cb8117c4ee2e9f66a8',
#      'url': 'https://api.github.com/repos/CMPUT301W18T05/Taskzilla/commits/ef0949edc619700882a741cb8117c4ee2e9f66a8'},
#     {'author': {'email': 'csun@ualberta.ca', 'name': 'myapplestory'},
#      'distinct': True,
#      'message': "Merge branch 'master' of https://github.com/CMPUT301W18T05/Taskzilla",
#      'sha': '7eeb8c642c63ca4adcf27d891afa65e54ea400bf',
#      'url': 'https://api.github.com/repos/CMPUT301W18T05/Taskzilla/commits/7eeb8c642c63ca4adcf27d891afa65e54ea400bf'},
#     {'author': {'email': 'csun@ualberta.ca', 'name': 'myapplestory'},
#      'distinct': True,
#      'message': 'deletes your higher bid when you make a new lower bid',
#      'sha': 'ca1633020718a2aba6ef4256617a0b87397006bb',
#      'url': 'https://api.github.com/repos/CMPUT301W18T05/Taskzilla/commits/ca1633020718a2aba6ef4256617a0b87397006bb'},
#     {'author': {'email': 'csun@ualberta.ca', 'name': 'myapplestory'},
#      'distinct': True,
#      'message': 'asd',
#      'sha': '2efa62492ad383acd3c01a2a619b21b0fd04bd51',
#      'url': 'https://api.github.com/repos/CMPUT301W18T05/Taskzilla/commits/2efa62492ad383acd3c01a2a619b21b0fd04bd51'}],
#    'distinct_size': 4,
#    'head': '2efa62492ad383acd3c01a2a619b21b0fd04bd51',
#    'push_id': 2411693004,
#    'ref': 'refs/heads/master',
#    'size': 4},
#   'public': True,
#   'repo': {'id': 120845847,
#    'name': 'CMPUT301W18T05/Taskzilla',
#    'url': 'https://api.github.com/repos/CMPUT301W18T05/Taskzilla'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'id': 8517910,
#    'login': 'LombiqBot',
#    'url': 'https://api.github.com/users/LombiqBot'},
#   'created_at': '2018-03-18T05:55:52Z',
#   'id': '7395970923',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?',
#    'gravatar_id': '',
#    'id': 8158177,
#    'login': 'Lombiq',
#    'url': 'https://api.github.com/orgs/Lombiq'},
#   'payload': {'before': '27178d9129c7b09c966034ea239c3076c0f2f299',
#    'commits': [],
#    'distinct_size': 0,
#    'head': '27178d9129c7b09c966034ea239c3076c0f2f299',
#    'push_id': 2411692997,
#    'ref': 'refs/heads/issue/BTLR-54',
#    'size': 0},
#   'public': True,
#   'repo': {'id': 46623531,
#    'name': 'Lombiq/Orchard-Antispam',
#    'url': 'https://api.github.com/repos/Lombiq/Orchard-Antispam'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/5991683?',
#    'display_login': 'tnessn',
#    'gravatar_id': '',
#    'id': 5991683,
#    'login': 'tnessn',
#    'url': 'https://api.github.com/users/tnessn'},
#   'created_at': '2018-03-18T05:55:52Z',
#   'id': '7395970922',
#   'payload': {'before': '5aa6b1e0493e84e1b1ed1aa93ecc57ed6b3c022d',
#    'commits': [{'author': {'email': '1005886607@qq.com',
#       'name': 'huangjinfeng'},
#      'distinct': True,
#      'message': '[maven-release-plugin] prepare release couscous-0.0.1',
#      'sha': 'ecd8d3551706d3ccf86a8528aeadb010e935cdcf',
#      'url': 'https://api.github.com/repos/tnessn/couscous/commits/ecd8d3551706d3ccf86a8528aeadb010e935cdcf'}],
#    'distinct_size': 1,
#    'head': 'ecd8d3551706d3ccf86a8528aeadb010e935cdcf',
#    'push_id': 2411692998,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 125152772,
#    'name': 'tnessn/couscous',
#    'url': 'https://api.github.com/repos/tnessn/couscous'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/11471197?',
#    'display_login': 'EMCain',
#    'gravatar_id': '',
#    'id': 11471197,
#    'login': 'EMCain',
#    'url': 'https://api.github.com/users/EMCain'},
#   'created_at': '2018-03-18T05:55:52Z',
#   'id': '7395970917',
#   'payload': {'action': 'opened',
#    'issue': {'assignee': None,
#     'assignees': [],
#     'author_association': 'OWNER',
#     'body': "from the Unity docs: \r\n\r\nhttps://docs.unity3d.com/ScriptReference/Coroutine.html\r\nhttps://docs.unity3d.com/ScriptReference/MonoBehaviour.html\r\nhttps://docs.unity3d.com/Manual/testing-editortestsrunner.html\r\n\r\nabout nUnit: \r\nhttps://github.com/nunit/docs/wiki/Assertions\r\nhttps://github.com/nunit/docs/wiki/Constraint-Model\r\nhttps://github.com/nunit/docs/wiki/Constraints\r\nhttps://github.com/nunit/docs/wiki/SetUp-and-TearDown\r\npretty much all the behavior I'd want to test is based in some way on Scenes in Unity, and so I need to figure out how to mock those. \r\n\r\n",
#     'closed_at': None,
#     'comments': 0,
#     'comments_url': 'https://api.github.com/repos/EMCain/RPG_base/issues/1/comments',
#     'created_at': '2018-03-18T05:55:52Z',
#     'events_url': 'https://api.github.com/repos/EMCain/RPG_base/issues/1/events',
#     'html_url': 'https://github.com/EMCain/RPG_base/issues/1',
#     'id': 306215681,
#     'labels': [{'color': '34c1b8',
#       'default': False,
#       'id': 870893912,
#       'name': 'research',
#       'url': 'https://api.github.com/repos/EMCain/RPG_base/labels/research'}],
#     'labels_url': 'https://api.github.com/repos/EMCain/RPG_base/issues/1/labels{/name}',
#     'locked': False,
#     'milestone': None,
#     'number': 1,
#     'repository_url': 'https://api.github.com/repos/EMCain/RPG_base',
#     'state': 'open',
#     'title': 'learn about concepts related to testing in Unity ',
#     'updated_at': '2018-03-18T05:55:52Z',
#     'url': 'https://api.github.com/repos/EMCain/RPG_base/issues/1',
#     'user': {'avatar_url': 'https://avatars2.githubusercontent.com/u/11471197?v=4',
#      'events_url': 'https://api.github.com/users/EMCain/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/EMCain/followers',
#      'following_url': 'https://api.github.com/users/EMCain/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/EMCain/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/EMCain',
#      'id': 11471197,
#      'login': 'EMCain',
#      'organizations_url': 'https://api.github.com/users/EMCain/orgs',
#      'received_events_url': 'https://api.github.com/users/EMCain/received_events',
#      'repos_url': 'https://api.github.com/users/EMCain/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/EMCain/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/EMCain/subscriptions',
#      'type': 'User',
#      'url': 'https://api.github.com/users/EMCain'}}},
#   'public': True,
#   'repo': {'id': 120257299,
#    'name': 'EMCain/RPG_base',
#    'url': 'https://api.github.com/repos/EMCain/RPG_base'},
#   'type': 'IssuesEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/9785902?',
#    'display_login': 'xiaoqufengchao',
#    'gravatar_id': '',
#    'id': 9785902,
#    'login': 'xiaoqufengchao',
#    'url': 'https://api.github.com/users/xiaoqufengchao'},
#   'created_at': '2018-03-18T05:55:52Z',
#   'id': '7395970916',
#   'payload': {'before': '1d795747d5b3701a728f76b48aeb95d4dd7b313a',
#    'commits': [{'author': {'email': 'jyshi@uci.edu', 'name': 'Jiayoushi'},
#      'distinct': True,
#      'message': '60 timeout',
#      'sha': '4cd2f930fe4a3382b4cdf119f3e3025cce272fb8',
#      'url': 'https://api.github.com/repos/xiaoqufengchao/wat/commits/4cd2f930fe4a3382b4cdf119f3e3025cce272fb8'}],
#    'distinct_size': 1,
#    'head': '4cd2f930fe4a3382b4cdf119f3e3025cce272fb8',
#    'push_id': 2411692995,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 124637181,
#    'name': 'xiaoqufengchao/wat',
#    'url': 'https://api.github.com/repos/xiaoqufengchao/wat'},
#   'type': 'PushEvent'}]

# %%
type(json_data)
# Out:
# list

# %%
for event in json_data:
    if event['type'] == "PushEvent":
        for commit in event['payload']['commits']:
            print("Commit {} message: {}".format(commit['sha'], commit['message']))
# Out:
# Commit fa0587fa3c4a09bd2941e7483dac9e832820b898 message: ELM
# Commit 4418a327b910b4b835b337b6978a020c9b5a1c75 message: update files
# Commit 0120183efd0ec5483c508913f8291d69af0ce36d message: Delete project_output.mp4
# Commit aad0bf0570e45c1f05bdcc937b117d549d8aba74 message: Update _config.yml
# Commit 242f98d7fa67e4297b62972c67e01c6b6f19f407 message: Update datasets Sun Mar 18 01:55:49 EDT 2018
# Commit 4459142ce9ac9af144852543baf649d0690c3a80 message: 200 OK http://sitl.diputados.gob.mx/LXIII_leg/curricula.php?dipt=442
# Commit f92b0d663f02152f3c41d144e753f60d836d1cc0 message: Changed hydras and added org agenda stuff
# Commit 084b1daac87dc566a3b77d6949c1d5d5f08932ac message: Create customsafelink.js
# Commit 917f458308ca93fe9ea76abe6ea2d5b6b6099493 message: openid
# Commit 8c78c1e92485d2969425fd0076c6f58072488ae2 message: Delete sgpas1.txt
# Commit 314900f54ed1db12b054788c8f52ef724e6f2431 message: fix for navbar background color after update bulma
# Commit ef0949edc619700882a741cb8117c4ee2e9f66a8 message: almost able to demove lower bid
# Commit 7eeb8c642c63ca4adcf27d891afa65e54ea400bf message: Merge branch 'master' of https://github.com/CMPUT301W18T05/Taskzilla
# Commit ca1633020718a2aba6ef4256617a0b87397006bb message: deletes your higher bid when you make a new lower bid
# Commit 2efa62492ad383acd3c01a2a619b21b0fd04bd51 message: asd
# Commit ecd8d3551706d3ccf86a8528aeadb010e935cdcf message: [maven-release-plugin] prepare release couscous-0.0.1
# Commit 4cd2f930fe4a3382b4cdf119f3e3025cce272fb8 message: 60 timeout

# %% [markdown]
# ### Making other types of HTTP requests

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
r = requests.put('http://httpbin.org/put', data = {'key':'value'})
r = requests.delete('http://httpbin.org/delete')
r = requests.head('http://httpbin.org/get')
r = requests.options('http://httpbin.org/get')

# %% [markdown]
# ### Passing Parameters In URLs

# %%
payload = {'key1': 'value1', 'key2': 'value2'}

# %%
r = requests.get('http://httpbin.org/get', params=payload)

# %%
print(r.url)
# Out:
# http://httpbin.org/get?key1=value1&key2=value2

# %% [markdown]
# Passing lists of parameters

# %%
payload = {'key1': 'value1', 'key2': ['value2', 'value3']}
r = requests.get('http://httpbin.org/get', params=payload)

# %%
print(r.url)
# Out:
# http://httpbin.org/get?key1=value1&key2=value2&key2=value3

# %% [markdown]
# ### Custom Headers

# %%
url = 'https://api.github.com/some/endpoint'
headers = {'user-agent': 'my-app/0.0.1'}
r = requests.get(url, headers=headers)

# %% [markdown]
# ### Further Info

# %% [markdown]
# See [Python Requests](http://docs.python-requests.org/en/master/)
